# %% [markdown]
# <a href="https://colab.research.google.com/github/lsmanoel/CEM_4/blob/master/python_aux/open_matrix_2d_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## CSV from Github:
#
# https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92

# %%
import pandas as pd

url_elc_plane_bottom_24_MHz = 'https://raw.githubusercontent.com/lsmanoel/CEM_4/master/13.06/placaL_medidas%20-%20%20plane_bottom_24_MHz.csv'
url_elc_plane_bottom_500_KHz = 'https://raw.githubusercontent.com/lsmanoel/CEM_4/master/13.06/placaL_medidas%20-%20plane_bottom_500_KHz.csv'
url_elc_plane_top_24_MHz = 'https://raw.githubusercontent.com/lsmanoel/CEM_4/master/13.06/placaL_medidas%20-%20plane_top_24_MHz.csv'
url_elc_plane_top_500_KHz = 'https://raw.githubusercontent.com/lsmanoel/CEM_4/master/13.06/placaL_medidas%20-%20plane_top_500_KHz.csv'
url_mag_plane_bottom_24_MHz = 'https://raw.githubusercontent.com/lsmanoel/CEM_4/master/13.06/placaL_medidas%20-%20mag_plane_bottom_24_MHz.csv'
url_mag_plane_top_24_MHz = 'https://raw.githubusercontent.com/lsmanoel/CEM_4/master/13.06/placaL_medidas%20-%20mag_plane_top_24_MHz.csv'

columns_name = ['A','B','C','D','E','F','G','H','I','J','K','L','M']

pd_elc_plane_bottom_24_MHz = pd.read_csv(url_elc_plane_bottom_24_MHz, names=columns_name)
pd_elc_plane_bottom_500_KHz = pd.read_csv(url_elc_plane_bottom_500_KHz, names=columns_name)
pd_elc_plane_top_24_MHz = pd.read_csv(url_elc_plane_top_24_MHz, names=columns_name)
pd_elc_plane_top_500_KHz = pd.read_csv(url_elc_plane_top_500_KHz, names=columns_name)
pd_mag_plane_bottom_24_MHz = pd.read_csv(url_mag_plane_bottom_24_MHz, names=columns_name)
pd_mag_plane_top_24_MHz = pd.read_csv(url_mag_plane_top_24_MHz, names=columns_name)

elc_plane_bottom_24_MHz = pd_elc_plane_bottom_24_MHz.values
elc_plane_bottom_500_KHz = pd_elc_plane_bottom_500_KHz.values
elc_plane_top_24_MHz = pd_elc_plane_top_24_MHz.values
elc_plane_top_500_KHz = pd_elc_plane_top_500_KHz.values
mag_plane_bottom_24_MHz = pd_mag_plane_bottom_24_MHz.values
mag_plane_top_24_MHz = pd_mag_plane_top_24_MHz.values

elc_plane_bottom_24_MHz = -elc_plane_bottom_24_MHz
elc_plane_bottom_500_KHz = -elc_plane_bottom_500_KHz
elc_plane_top_24_MHz = -elc_plane_top_24_MHz
elc_plane_top_500_KHz = -elc_plane_top_500_KHz
mag_plane_bottom_24_MHz = -mag_plane_bottom_24_MHz
mag_plane_top_24_MHz = -mag_plane_top_24_MHz

# %%
pd_elc_plane_bottom_24_MHz

# %% [markdown]
# ---
# ##  Plot 2d: Global Config

# %%
global_scale = (10, -60)
private_scale = ( 0, -70)

# %% [markdown]
# ---
# ##  Plot 2d: Top - 500  KHz - Elétrico

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================  
fig = plt.figure(figsize=(11,22))

# ==============================================================================  
ax = fig.add_subplot(2, 1, 1)
ax.set_title('elc_plane_top_500_KHz - private scale')

img = ax.imshow(elc_plane_top_500_KHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = private_scale[0],
                vmin = private_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

# ==============================================================================  
ax = fig.add_subplot(2, 1, 2)
ax.set_title('elc_plane_top_500_KHz - global scale')

img = ax.imshow(elc_plane_top_500_KHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = global_scale[0],
                vmin = global_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

#===============================================================================
plt.show()

# %% [markdown]
# ---
# ##  Plot 2d: Botton - 500  KHz  - Elétrico

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================  
fig = plt.figure(figsize=(11,22))

# ==============================================================================  
ax = fig.add_subplot(2, 1, 1)
ax.set_title('elc_plane_bottom_500_KHz - private scale')

img = ax.imshow(elc_plane_bottom_500_KHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = private_scale[0],
                vmin = private_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

# ==============================================================================  
ax = fig.add_subplot(2, 1, 2)
ax.set_title('elc_plane_bottom_500_KHz - global scale')

img = ax.imshow(elc_plane_bottom_500_KHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = global_scale[0],
                vmin = global_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

#===============================================================================
plt.show()

# %% [markdown]
# ---
# ##  Plot 2d: Top - 24  MHz  - Elétrico

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================  
fig = plt.figure(figsize=(11,22))

# ==============================================================================  
ax = fig.add_subplot(2, 1, 1)
ax.set_title('elc_plane_top_24_MHz - private scale')

img = ax.imshow(elc_plane_top_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = private_scale[0],
                vmin = private_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

# ==============================================================================  
ax = fig.add_subplot(2, 1, 2)
ax.set_title('elc_plane_top_24_MHz - global scale')

img = ax.imshow(elc_plane_top_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = global_scale[0],
                vmin = global_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

#===============================================================================
plt.show()

# %% [markdown]
# ---
# ##  Plot 2d: Botton - 24  MHz  - Elétrico

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================  
fig = plt.figure(figsize=(11,22))

# ==============================================================================  
ax = fig.add_subplot(2, 1, 1)
ax.set_title('elc_plane_bottom_24_MHz - private scale')

img = ax.imshow(elc_plane_bottom_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = private_scale[0],
                vmin = private_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

# ==============================================================================  
ax = fig.add_subplot(2, 1, 2)
ax.set_title('elc_plane_bottom_24_MHz - global scale')

img = ax.imshow(elc_plane_bottom_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = global_scale[0],
                vmin = global_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

#===============================================================================
plt.show()

# %% [markdown]
# ---
# ##  Plot 2d: Top - 24  MHz  - Magnético

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================  
fig = plt.figure(figsize=(11,22))

# ==============================================================================  
ax = fig.add_subplot(2, 1, 1)
ax.set_title('mag_plane_top_24_MHz - private scale')

img = ax.imshow(mag_plane_top_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = private_scale[0],
                vmin = private_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

# ==============================================================================  
ax = fig.add_subplot(2, 1, 2)
ax.set_title('mag_plane_top_24_MHz - global scale')

img = ax.imshow(mag_plane_top_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = global_scale[0],
                vmin = global_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

#===============================================================================
plt.show()

# %% [markdown]
# ---
# ##  Plot 2d: Botton - 24  MHz Magnético

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================  
fig = plt.figure(figsize=(11,22))

# ==============================================================================  
ax = fig.add_subplot(2, 1, 1)
ax.set_title('mag_plane_botton_24_MHz - private scale')

img = ax.imshow(mag_plane_bottom_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = private_scale[0],
                vmin = private_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

# ==============================================================================  
ax = fig.add_subplot(2, 1, 2)
ax.set_title('mag_plane_botton_24_MHz - global scale')

img = ax.imshow(mag_plane_bottom_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = global_scale[0],
                vmin = global_scale[1])

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

#===============================================================================
plt.show()

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================  
fig = plt.figure(figsize=(11,22))

# ==============================================================================  
ax = fig.add_subplot(2, 1, 1)
ax.set_title('Top')

img = ax.imshow(elc_plane_top_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = 0,
                vmin = -80)

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

# ==============================================================================  
ax = fig.add_subplot(2, 1, 2)
ax.set_title('Botton')

img = ax.imshow(elc_plane_bottom_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = 0,
                vmin = -80)

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

#===============================================================================
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================  
fig = plt.figure(figsize=(11,8))

# ==============================================================================  
ax = fig.add_subplot(1, 1, 1)

img = ax.imshow(mag_plane_bottom_24_MHz, 
                interpolation ='gaussian', 
                cmap ='inferno',
                vmax = 0,
                vmin = -80)

fig.colorbar(img, ax=ax)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])

ax.set_xticks(np.arange(0,13,1)) 
ax.set_yticks(np.arange(0,13,1)) 

ax.grid(True)

# ==============================================================================
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
from mpl_toolkits.mplot3d.axes3d import get_test_data
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

# ==============================================================================
fig = plt.figure(figsize=plt.figaspect(0.25))

# ==============================================================================
# set up the axes for the first plot
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.set_title('Antialiased True')

X = np.arange(0, 13, 1)
Y = np.arange(0, 13, 1)
X, Y = np.meshgrid(X, Y)

Z = elc_plane_bottom_24_MHz

surf = ax.plot_surface(X, Y, Z, 
                       rstride=1, 
                       cstride=1, 
                       cmap ='inferno',
                       linewidth=0, 
                       antialiased=True,
                       vmax = 0,
                       vmin = -80)

fig.colorbar(surf, shrink=0.5, aspect=10)
ax.set_zlim(-80, 0)

angle_view = 120
ax.view_init(45, angle_view)

# ==============================================================================
# set up the axes for the second plot
ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.set_title('Antialiased False')

X = np.arange(0, 13, 1)
Y = np.arange(0, 13, 1)
X, Y = np.meshgrid(X, Y)

Z = elc_plane_bottom_24_MHz

surf = ax.plot_surface(X, Y, Z, 
                       rstride=1, 
                       cstride=1, 
                       cmap ='inferno',
                       linewidth=0, 
                       antialiased=False,
                       vmax = 0,
                       vmin = -80)

fig.colorbar(surf, shrink=0.5, aspect=10)
ax.set_zlim(-80, 0)

angle_view = 120
ax.view_init(45, angle_view)

# ==============================================================================
plt.show()

# %% [markdown]
# ---
# ## Interpolate
#
#  https://docs.scipy.org/doc/scipy/reference/tutorial/interpolate.html

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
from mpl_toolkits.mplot3d.axes3d import get_test_data
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
from scipy import interpolate

# ==============================================================================
fig = plt.figure(figsize=plt.figaspect(0.25))

# ==============================================================================
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.set_title('Interpolated')

X = np.arange(0, 13, 1)
Y = np.arange(0, 13, 1)
X, Y = np.meshgrid(X, Y)

Z = mag_plane_bottom_24_MHz

# ------------------------------------------------------------------------------
# Interpolation
tck = interpolate.bisplrep(X, Y, Z, s=0)

ratio = 10

X_interp = np.arange(0, 13, 1/ratio)
Y_interp = np.arange(0, 13, 1/ratio)

X_interp, Y_interp = np.mgrid[0:13:ratio*13j, 0:13:ratio*13j]

Z_interp = interpolate.bisplev(X_interp[:,0], Y_interp[0,:], tck)
    
surf = ax.plot_surface(X_interp, Y_interp, Z_interp, 
                       rstride=1, 
                       cstride=1, 
                       cmap ='inferno',
                       linewidth=0, 
                       antialiased=True,
                       vmax = 0,
                       vmin = -80)

fig.colorbar(surf, shrink=0.5, aspect=10)
ax.set_zlim(-80, 0)

angle_view = 120
ax.view_init(60, angle_view)

# ==============================================================================
ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.set_title('No Interpolated')

X = np.arange(0, 13, 1)
Y = np.arange(0, 13, 1)
X, Y = np.meshgrid(X, Y)
Z = mag_plane_bottom_24_MHz

surf = ax.plot_surface(X, Y, Z, 
                       rstride=1, 
                       cstride=1, 
                       cmap ='inferno',
                       linewidth=0, 
                       antialiased=True,
                       vmax = 0,
                       vmin = -80)

fig.colorbar(surf, shrink=0.5, aspect=10)
ax.set_zlim(-80, 0)

angle_view = 120
ax.view_init(60, angle_view)

# ==============================================================================
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
from mpl_toolkits.mplot3d.axes3d import get_test_data
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
from scipy import interpolate

# ==============================================================================
fig = plt.figure(figsize=(11,8))

# ==============================================================================
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.set_title('Interpolated')

X = np.arange(0, 13, 1)
Y = np.arange(0, 13, 1)
X, Y = np.meshgrid(X, Y)

Z = elc_plane_top_500_KHz

# ------------------------------------------------------------------------------
# Interpolation
tck = interpolate.bisplrep(X, Y, Z, s=250)

ratio = 10

X_interp = np.arange(0, 13, 1/ratio)
Y_interp = np.arange(0, 13, 1/ratio)

X_interp, Y_interp = np.mgrid[0:13:ratio*13j, 0:13:ratio*13j]

Z_interp = interpolate.bisplev(X_interp[:,0], Y_interp[0,:], tck)
    
surf = ax.plot_surface(X_interp, Y_interp, Z_interp, 
                       rstride=1, 
                       cstride=1, 
                       cmap ='inferno',
                       linewidth=0, 
                       antialiased=True,
                       vmax = 0,
                       vmin = -80)

fig.colorbar(surf, shrink=0.5, aspect=10)
ax.set_zlim(-80, 0)

angle_view = 120
ax.view_init(45, angle_view)

# ==============================================================================
plt.show()
